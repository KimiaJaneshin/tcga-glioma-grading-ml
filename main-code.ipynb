# %% [markdown]
# <a href="https://colab.research.google.com/github/KimiaJaneshin/tcga-glioma-grading-ml/blob/main/main-code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================================================
# INSTALLS
# =========================================================
# !pip install -q kagglehub xgboost lightgbm shap pytorch-tabnet

import kagglehub
import numpy as np
import pandas as pd
import shap
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import os

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    roc_auc_score, accuracy_score, f1_score,
    precision_score, recall_score, brier_score_loss,
    confusion_matrix, precision_recall_curve
)

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
import lightgbm as lgb
from pytorch_tabnet.tab_model import TabNetClassifier

RANDOM_STATE = 42
N_SPLITS = 5

SCALED_MODELS = {"Logistic Regression", "TabNet"}
# =========================================================
# DOWNLOAD + LOAD DATA
# =========================================================
path = kagglehub.dataset_download("vinayjose/glioma-grading-clinical-and-mutation-features")

print("Path to dataset files:", path)

df = pd.read_csv(os.path.join(path, "TCGA_InfoWithGrade.csv"))

TARGET = "Grade"

print("Original Grade values:")
print(df[TARGET].value_counts(dropna=False))
print("Unique values:", df[TARGET].unique())


if pd.api.types.is_numeric_dtype(df[TARGET]):
    print("Grade is already numeric.")
else:
    df[TARGET] = df[TARGET].astype(str).str.strip().str.upper()

    print("\nCleaned Grade values:")
    print(df[TARGET].value_counts(dropna=False))


    if set(df[TARGET].dropna().unique()).issubset({"LGG", "GBM"}):
        df[TARGET] = df[TARGET].map({"LGG": 0, "GBM": 1})
    else:
        print("\nGrade values are not LGG/GBM, so custom mapping is needed.")
        print("Current unique values:", df[TARGET].dropna().unique())
print("\nAfter possible mapping:")
print(df[TARGET].value_counts(dropna=False))

df = df.dropna(subset=[TARGET]).copy()

print("\nShape after dropping missing target:", df.shape)

X = df.drop(columns=[TARGET])
X = pd.get_dummies(X, drop_first=True)
X = X.fillna(0)
y = df[TARGET].values

print("X shape:", X.shape)
print("y shape:", y.shape)

# ==============================
# CROSS VALIDATION
# ==============================

skf = StratifiedKFold(
    n_splits=N_SPLITS,
    shuffle=True,
    random_state=RANDOM_STATE
)

models = {

    "Logistic Regression":
        LogisticRegression(max_iter=2000),

    "Random Forest":
        RandomForestClassifier(
            n_estimators=800,
            max_depth=10,
            class_weight="balanced",
            random_state=RANDOM_STATE
        ),

    "XGBoost":
        XGBClassifier(
            n_estimators=500,
            learning_rate=0.03,
            max_depth=4,
            subsample=0.9,
            colsample_bytree=0.9,
            reg_lambda=1.0,
            reg_alpha=0.2,
            eval_metric="logloss",
            random_state=RANDOM_STATE
        ),

    "LightGBM":
        lgb.LGBMClassifier(
            n_estimators=300,
            learning_rate=0.03,
            num_leaves=15,
            max_depth=4,
            subsample=0.9,
            colsample_bytree=0.9,
            reg_alpha=0.2,
            reg_lambda=1.0,
            verbose=-1,
            random_state=RANDOM_STATE
        ),

    "TabNet":
        TabNetClassifier(
            n_d=64,
            n_a=64,
            n_steps=5,
            gamma=1.7,
            lambda_sparse=1e-4,
            optimizer_fn=torch.optim.Adam,
            optimizer_params=dict(lr=2e-3),
            seed=RANDOM_STATE
        )
}

oof_preds = {name: np.zeros(len(y)) for name in models}
results = []

# ==============================
# TRAINING
# ==============================
# ==============================
# TRAINING (clean scaling)
# ==============================

for name, model in models.items():
    print("\nTraining", name)
    fold_aucs = []

    for fold, (train_idx, test_idx) in enumerate(skf.split(X, y), start=1):
        X_train_raw, X_test_raw = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]


        if name in SCALED_MODELS:
            scaler = StandardScaler()
            X_train = scaler.fit_transform(X_train_raw)
            X_test  = scaler.transform(X_test_raw)
        else:

            X_train = X_train_raw.to_numpy()
            X_test  = X_test_raw.to_numpy()

        if name == "TabNet":
           tabnet = TabNetClassifier(
                n_d=64,
                n_a=64,
                n_steps=5,
                gamma=1.7,
                lambda_sparse=1e-4,
                optimizer_fn=torch.optim.Adam,
                optimizer_params=dict(lr=2e-3),
                seed=RANDOM_STATE
            )

           tabnet.fit(
                X_train,
                y_train,
                eval_set=[(X_test, y_test)],
                eval_metric=["auc"],
                patience=20,
                max_epochs=200,
                batch_size=256
            )
           preds = tabnet.predict_proba(X_test)[:, 1]

        else:

            model.fit(X_train, y_train)
            preds = model.predict_proba(X_test)[:, 1]

        oof_preds[name][test_idx] = preds

        auc = roc_auc_score(y_test, preds)
        fold_aucs.append(auc)
        print(f"Fold {fold} AUC: {auc:.4f}")

    print(f"{name} Mean AUC: {np.mean(fold_aucs):.4f}")


# ==============================
# THRESHOLD OPTIMIZATION
# ==============================

best_thresholds = {}

for name, probs in oof_preds.items():

    precision, recall, thresholds = precision_recall_curve(y, probs)

    f1_scores = 2 * precision * recall / (precision + recall + 1e-9)

    best_idx = np.argmax(f1_scores)

    best_thresholds[name] = thresholds[best_idx]

    print(
        name,
        "Best threshold:",
        round(thresholds[best_idx],4),
        "Best F1:",
        round(f1_scores[best_idx],4)
    )

# ==============================
# FINAL METRICS
# ==============================

for name, probs in oof_preds.items():

    threshold = best_thresholds[name]

    preds = (probs >= threshold).astype(int)

    auc = roc_auc_score(y, probs)
    acc = accuracy_score(y, preds)
    f1 = f1_score(y, preds)
    precision = precision_score(y, preds)
    recall = recall_score(y, preds)
    brier = brier_score_loss(y, probs)

    results.append({
        "Model": name,
        "AUC": auc,
        "Accuracy": acc,
        "F1": f1,
        "Precision": precision,
        "Recall": recall,
        "Brier": brier
    })

results_df = pd.DataFrame(results).sort_values("AUC", ascending=False)

print("\nFinal Results")
print(results_df)

# ==============================
# CONFUSION MATRICES
# ==============================

for name, probs in oof_preds.items():
    preds = (probs >= best_thresholds[name]).astype(int)
    cm = confusion_matrix(y, preds)

    plt.figure(figsize=(6, 5))
    sns.heatmap(
        cm,
        annot=True,
        fmt="d",
        cmap="Blues",
        cbar=False,
        xticklabels=["LGG (0)", "GBM (1)"],
        yticklabels=["LGG (0)", "GBM (1)"],
        annot_kws={"size": 16, "weight": "bold"}
    )

    plt.title(f"{name}\nConfusion Matrix", fontsize=14, pad=12)
    plt.xlabel("Predicted Grade", fontsize=12, labelpad=10)
    plt.ylabel("True Grade", fontsize=12, labelpad=10)


    plt.tight_layout()

    filename = name.lower().replace(" ", "_") + "_cm_clean.png"
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    plt.show()

# ==============================
# BOOTSTRAP AUC CONFIDENCE INTERVAL
# ==============================

def bootstrap_auc(y_true, y_pred, n_bootstrap=2000):

    rng = np.random.RandomState(42)
    scores = []

    for i in range(n_bootstrap):

        idx = rng.randint(0, len(y_true), len(y_true))

        if len(np.unique(y_true[idx])) < 2:
            continue

        score = roc_auc_score(y_true[idx], y_pred[idx])
        scores.append(score)

    return np.percentile(scores, [2.5, 97.5])

print("\nAUC 95% Confidence Intervals")

for name, probs in oof_preds.items():

    ci = bootstrap_auc(y, probs)

    print(name, "CI:", ci)

# ==============================
# DECISION CURVE ANALYSIS
# ==============================

import numpy as np
import matplotlib.pyplot as plt

thresholds = np.linspace(0.01, 0.99, 100)
n = len(y)
prevalence = np.mean(y)


curves = {}
for name, probs in oof_preds.items():
    net_benefits = []
    for t in thresholds:
        preds = (probs >= t).astype(int)
        tp = np.sum((preds == 1) & (y == 1))
        fp = np.sum((preds == 1) & (y == 0))
        nb = (tp / n) - (fp / n) * (t / (1 - t))
        net_benefits.append(nb)
    curves[name] = np.array(net_benefits)

treat_all = prevalence - (1 - prevalence) * (thresholds / (1 - thresholds))
treat_none = np.zeros_like(thresholds)


all_model_vals = np.concatenate(list(curves.values()))
ymax_full = np.max(all_model_vals) + 0.05
ymin_full = -0.10


fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(11, 14))

# PLOT 1: FULL OVERVIEW (Panel A)
for name, nb in curves.items():
    ax1.plot(thresholds, nb, label=name, lw=2.5)

ax1.plot(thresholds, treat_none, color="black", linestyle="--", lw=1.5, label="Treat None")
ax1.plot(thresholds, treat_all, color="gray", linestyle="--", lw=1.5, alpha=0.7, label="Treat All")

ax1.set_xlim(0.0, 1.0)
ax1.set_ylim(ymin_full, ymax_full)
ax1.set_title("Decision Curve Analysis: Full Perspective (0.0 - 1.0)", fontsize=15, fontweight='bold', pad=15)
ax1.set_ylabel("Net Benefit", fontsize=12)
ax1.legend(loc="upper right", frameon=True, fontsize=10)
ax1.grid(True, alpha=0.3)

# PLOT 2: CLINICAL ZOOM (Panel B)
for name, nb in curves.items():
    ax2.plot(thresholds, nb, label=name, lw=2.5)

ax2.plot(thresholds, treat_none, color="black", linestyle="--", lw=1.5, label="Treat None")
ax2.plot(thresholds, treat_all, color="gray", linestyle="--", lw=1.5, alpha=0.7, label="Treat All")

ax2.set_xlim(0.50, 0.85)
ax2.set_ylim(-0.02, 0.20)
ax2.set_title("Clinical Utility: Target Threshold Zoom (0.50 - 0.85)", fontsize=15, fontweight='bold', pad=15)
ax2.set_xlabel("Threshold Probability", fontsize=12)
ax2.set_ylabel("Net Benefit", fontsize=12)
ax2.legend(loc="lower left", frameon=True, fontsize=10)
ax2.grid(True, alpha=0.3)

plt.tight_layout(pad=4.0)
plt.savefig("dca_portfolio_dual_panel.png", dpi=300, bbox_inches="tight")
plt.show()


# ==============================
# SHAP ANALYSIS (XGBoost)
# ==============================

print("\nRunning SHAP analysis")

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

xgb_model = XGBClassifier(
    n_estimators=500,
    learning_rate=0.03,
    max_depth=4,
    subsample=0.9,
    colsample_bytree=0.9,
    reg_lambda=1.0,
    reg_alpha=0.2,
    eval_metric="logloss",
    random_state=42
)

xgb_model.fit(X_scaled, y)

explainer = shap.TreeExplainer(xgb_model)

shap_values = explainer.shap_values(X_scaled)

shap.summary_plot(shap_values, X, show=False)
plt.title("SHAP Feature Importance (XGBoost)", fontsize=14, pad=12)
plt.tight_layout()
plt.savefig("shap_xgboost_summary.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.5/44.5 kB 618.6 kB/s eta 0:00:00
# Using Colab cache for faster access to the 'glioma-grading-clinical-and-mutation-features' dataset.
# Path to dataset files: /kaggle/input/glioma-grading-clinical-and-mutation-features
# Original Grade values:
# Grade
# 0    487
# 1    352
# Name: count, dtype: int64
# Unique values: [0 1]
# Grade is already numeric.
#
# After possible mapping:
# Grade
# 0    487
# 1    352
# Name: count, dtype: int64
#
# Shape after dropping missing target: (839, 24)
# X shape: (839, 23)
# y shape: (839,)
#
# Training Logistic Regression
# Fold 1 AUC: 0.9220
# Fold 2 AUC: 0.9140
# Fold 3 AUC: 0.9244
# Fold 4 AUC: 0.9228
# Fold 5 AUC: 0.9013
# Logistic Regression Mean AUC: 0.9169
#
# Training Random Forest
# /usr/local/lib/python3.12/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# Fold 1 AUC: 0.9284
# Fold 2 AUC: 0.9207
# Fold 3 AUC: 0.9198
# Fold 4 AUC: 0.9404
# Fold 5 AUC: 0.9101
# Random Forest Mean AUC: 0.9239
#
# Training XGBoost
# Fold 1 AUC: 0.9252
# Fold 2 AUC: 0.9144
# Fold 3 AUC: 0.9106
# Fold 4 AUC: 0.9413
# Fold 5 AUC: 0.9052
# XGBoost Mean AUC: 0.9193
#
# Training LightGBM
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# Fold 1 AUC: 0.9284
# Fold 2 AUC: 0.9192
# Fold 3 AUC: 0.9065
# Fold 4 AUC: 0.9296
# Fold 5 AUC: 0.9113
# LightGBM Mean AUC: 0.9190
#
# Training TabNet
# /usr/local/lib/python3.12/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 0.90146 | val_0_auc: 0.44694 |  0:00:00s
# epoch 1  | loss: 0.88794 | val_0_auc: 0.62544 |  0:00:00s
# epoch 2  | loss: 0.87504 | val_0_auc: 0.6801  |  0:00:00s
# epoch 3  | loss: 0.84026 | val_0_auc: 0.67238 |  0:00:00s
# epoch 4  | loss: 0.75215 | val_0_auc: 0.67114 |  0:00:01s
# epoch 5  | loss: 0.74921 | val_0_auc: 0.72238 |  0:00:01s
# epoch 6  | loss: 0.70843 | val_0_auc: 0.70357 |  0:00:01s
# epoch 7  | loss: 0.6899  | val_0_auc: 0.77449 |  0:00:01s
# epoch 8  | loss: 0.56429 | val_0_auc: 0.79599 |  0:00:01s
# epoch 9  | loss: 0.63483 | val_0_auc: 0.80525 |  0:00:01s
# epoch 10 | loss: 0.64324 | val_0_auc: 0.80197 |  0:00:02s
# epoch 11 | loss: 0.5939  | val_0_auc: 0.80671 |  0:00:02s
# epoch 12 | loss: 0.53444 | val_0_auc: 0.8172  |  0:00:02s
# epoch 13 | loss: 0.55394 | val_0_auc: 0.78557 |  0:00:02s
# epoch 14 | loss: 0.62282 | val_0_auc: 0.81079 |  0:00:02s
# epoch 15 | loss: 0.50531 | val_0_auc: 0.82157 |  0:00:02s
# epoch 16 | loss: 0.56229 | val_0_auc: 0.81574 |  0:00:02s
# epoch 17 | loss: 0.53723 | val_0_auc: 0.83848 |  0:00:03s
# epoch 18 | loss: 0.47748 | val_0_auc: 0.84402 |  0:00:03s
# epoch 19 | loss: 0.46318 | val_0_auc: 0.84927 |  0:00:03s
# epoch 20 | loss: 0.46208 | val_0_auc: 0.8535  |  0:00:03s
# epoch 21 | loss: 0.51831 | val_0_auc: 0.86268 |  0:00:03s
# epoch 22 | loss: 0.4782  | val_0_auc: 0.87434 |  0:00:03s
# epoch 23 | loss: 0.45433 | val_0_auc: 0.87507 |  0:00:04s
# epoch 24 | loss: 0.43718 | val_0_auc: 0.87114 |  0:00:04s
# epoch 25 | loss: 0.4806  | val_0_auc: 0.86574 |  0:00:04s
# epoch 26 | loss: 0.45474 | val_0_auc: 0.8812  |  0:00:04s
# epoch 27 | loss: 0.4566  | val_0_auc: 0.89694 |  0:00:04s
# epoch 28 | loss: 0.42745 | val_0_auc: 0.88601 |  0:00:04s
# epoch 29 | loss: 0.48877 | val_0_auc: 0.89213 |  0:00:05s
# epoch 30 | loss: 0.46827 | val_0_auc: 0.87595 |  0:00:05s
# epoch 31 | loss: 0.50345 | val_0_auc: 0.87711 |  0:00:05s
# epoch 32 | loss: 0.49804 | val_0_auc: 0.87536 |  0:00:05s
# epoch 33 | loss: 0.49869 | val_0_auc: 0.89169 |  0:00:05s
# epoch 34 | loss: 0.43551 | val_0_auc: 0.90204 |  0:00:05s
# epoch 35 | loss: 0.48585 | val_0_auc: 0.89111 |  0:00:06s
# epoch 36 | loss: 0.43288 | val_0_auc: 0.88236 |  0:00:06s
# epoch 37 | loss: 0.42887 | val_0_auc: 0.87566 |  0:00:06s
# epoch 38 | loss: 0.47309 | val_0_auc: 0.88294 |  0:00:06s
# epoch 39 | loss: 0.41718 | val_0_auc: 0.87872 |  0:00:06s
# epoch 40 | loss: 0.44444 | val_0_auc: 0.8812  |  0:00:06s
# epoch 41 | loss: 0.47547 | val_0_auc: 0.88688 |  0:00:06s
# epoch 42 | loss: 0.46929 | val_0_auc: 0.88149 |  0:00:07s
# epoch 43 | loss: 0.44384 | val_0_auc: 0.87274 |  0:00:07s
# epoch 44 | loss: 0.42078 | val_0_auc: 0.86501 |  0:00:07s
# epoch 45 | loss: 0.44896 | val_0_auc: 0.86589 |  0:00:07s
# epoch 46 | loss: 0.41166 | val_0_auc: 0.87813 |  0:00:07s
# epoch 47 | loss: 0.42278 | val_0_auc: 0.88309 |  0:00:07s
# epoch 48 | loss: 0.39037 | val_0_auc: 0.88601 |  0:00:08s
# epoch 49 | loss: 0.34035 | val_0_auc: 0.86983 |  0:00:08s
# epoch 50 | loss: 0.43626 | val_0_auc: 0.87595 |  0:00:08s
# epoch 51 | loss: 0.43415 | val_0_auc: 0.88776 |  0:00:08s
# epoch 52 | loss: 0.49366 | val_0_auc: 0.87726 |  0:00:08s
# epoch 53 | loss: 0.38614 | val_0_auc: 0.88076 |  0:00:08s
# epoch 54 | loss: 0.40339 | val_0_auc: 0.87901 |  0:00:08s
#
# Early stopping occurred at epoch 54 with best_epoch = 34 and best_val_0_auc = 0.90204
# Fold 1 AUC: 0.9020
# /usr/local/lib/python3.12/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /usr/local/lib/python3.12/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 0.89369 | val_0_auc: 0.58768 |  0:00:00s
# epoch 1  | loss: 0.8063  | val_0_auc: 0.66195 |  0:00:00s
# epoch 2  | loss: 0.78004 | val_0_auc: 0.70794 |  0:00:00s
# epoch 3  | loss: 0.84909 | val_0_auc: 0.74417 |  0:00:00s
# epoch 4  | loss: 0.61782 | val_0_auc: 0.71356 |  0:00:00s
# epoch 5  | loss: 0.69566 | val_0_auc: 0.7199  |  0:00:01s
# epoch 6  | loss: 0.60024 | val_0_auc: 0.69796 |  0:00:01s
# epoch 7  | loss: 0.6069  | val_0_auc: 0.70729 |  0:00:01s
# epoch 8  | loss: 0.5892  | val_0_auc: 0.72777 |  0:00:01s
# epoch 9  | loss: 0.663   | val_0_auc: 0.74832 |  0:00:01s
# epoch 10 | loss: 0.64614 | val_0_auc: 0.79708 |  0:00:02s
# epoch 11 | loss: 0.64478 | val_0_auc: 0.83834 |  0:00:02s
# epoch 12 | loss: 0.49818 | val_0_auc: 0.82216 |  0:00:02s
# epoch 13 | loss: 0.56504 | val_0_auc: 0.82376 |  0:00:02s
# epoch 14 | loss: 0.46154 | val_0_auc: 0.83732 |  0:00:03s
# epoch 15 | loss: 0.54349 | val_0_auc: 0.83397 |  0:00:03s
# epoch 16 | loss: 0.55451 | val_0_auc: 0.84052 |  0:00:03s
# epoch 17 | loss: 0.51121 | val_0_auc: 0.83192 |  0:00:03s
# epoch 18 | loss: 0.5458  | val_0_auc: 0.83732 |  0:00:04s
# epoch 19 | loss: 0.50113 | val_0_auc: 0.84344 |  0:00:04s
# epoch 20 | loss: 0.45461 | val_0_auc: 0.85437 |  0:00:04s
# epoch 21 | loss: 0.47813 | val_0_auc: 0.85933 |  0:00:04s
# epoch 22 | loss: 0.52032 | val_0_auc: 0.85554 |  0:00:04s
# epoch 23 | loss: 0.48281 | val_0_auc: 0.87055 |  0:00:04s
# epoch 24 | loss: 0.49442 | val_0_auc: 0.88222 |  0:00:05s
# epoch 25 | loss: 0.49387 | val_0_auc: 0.90044 |  0:00:05s
# epoch 26 | loss: 0.44691 | val_0_auc: 0.8895  |  0:00:05s
# epoch 27 | loss: 0.49053 | val_0_auc: 0.88863 |  0:00:05s
# epoch 28 | loss: 0.40703 | val_0_auc: 0.88353 |  0:00:05s
# epoch 29 | loss: 0.42731 | val_0_auc: 0.87434 |  0:00:05s
# epoch 30 | loss: 0.43646 | val_0_auc: 0.88003 |  0:00:05s
# epoch 31 | loss: 0.47089 | val_0_auc: 0.87784 |  0:00:06s
# epoch 32 | loss: 0.4659  | val_0_auc: 0.87464 |  0:00:06s
# epoch 33 | loss: 0.4455  | val_0_auc: 0.88601 |  0:00:06s
# epoch 34 | loss: 0.48847 | val_0_auc: 0.89446 |  0:00:06s
# epoch 35 | loss: 0.42195 | val_0_auc: 0.89708 |  0:00:06s
# epoch 36 | loss: 0.44987 | val_0_auc: 0.87026 |  0:00:06s
# epoch 37 | loss: 0.38439 | val_0_auc: 0.89169 |  0:00:07s
# epoch 38 | loss: 0.40033 | val_0_auc: 0.89271 |  0:00:07s
# epoch 39 | loss: 0.43663 | val_0_auc: 0.89475 |  0:00:07s
# epoch 40 | loss: 0.46049 | val_0_auc: 0.90087 |  0:00:07s
# epoch 41 | loss: 0.42806 | val_0_auc: 0.89519 |  0:00:07s
# epoch 42 | loss: 0.45286 | val_0_auc: 0.90292 |  0:00:07s
# epoch 43 | loss: 0.40391 | val_0_auc: 0.90299 |  0:00:08s
# epoch 44 | loss: 0.37384 | val_0_auc: 0.90299 |  0:00:08s
# epoch 45 | loss: 0.39545 | val_0_auc: 0.90576 |  0:00:08s
# epoch 46 | loss: 0.40005 | val_0_auc: 0.89694 |  0:00:08s
# epoch 47 | loss: 0.35245 | val_0_auc: 0.89198 |  0:00:08s
# epoch 48 | loss: 0.42639 | val_0_auc: 0.88061 |  0:00:08s
# epoch 49 | loss: 0.36823 | val_0_auc: 0.88338 |  0:00:09s
# epoch 50 | loss: 0.36512 | val_0_auc: 0.89031 |  0:00:09s
# epoch 51 | loss: 0.38136 | val_0_auc: 0.88812 |  0:00:09s
# epoch 52 | loss: 0.3668  | val_0_auc: 0.89417 |  0:00:09s
# epoch 53 | loss: 0.406   | val_0_auc: 0.90233 |  0:00:09s
# epoch 54 | loss: 0.42904 | val_0_auc: 0.90044 |  0:00:09s
# epoch 55 | loss: 0.41936 | val_0_auc: 0.89869 |  0:00:09s
# epoch 56 | loss: 0.39125 | val_0_auc: 0.89504 |  0:00:10s
# epoch 57 | loss: 0.40412 | val_0_auc: 0.89009 |  0:00:10s
# epoch 58 | loss: 0.35472 | val_0_auc: 0.88834 |  0:00:10s
# epoch 59 | loss: 0.37737 | val_0_auc: 0.89767 |  0:00:10s
# epoch 60 | loss: 0.36138 | val_0_auc: 0.90262 |  0:00:10s
# epoch 61 | loss: 0.41615 | val_0_auc: 0.90758 |  0:00:10s
# epoch 62 | loss: 0.37165 | val_0_auc: 0.90838 |  0:00:11s
# epoch 63 | loss: 0.38233 | val_0_auc: 0.90882 |  0:00:11s
# epoch 64 | loss: 0.36412 | val_0_auc: 0.90335 |  0:00:11s
# epoch 65 | loss: 0.34993 | val_0_auc: 0.9027  |  0:00:11s
# epoch 66 | loss: 0.3623  | val_0_auc: 0.90415 |  0:00:11s
# epoch 67 | loss: 0.34761 | val_0_auc: 0.89891 |  0:00:11s
# epoch 68 | loss: 0.37874 | val_0_auc: 0.90248 |  0:00:12s
# epoch 69 | loss: 0.36312 | val_0_auc: 0.90102 |  0:00:12s
# epoch 70 | loss: 0.35155 | val_0_auc: 0.8973  |  0:00:12s
# epoch 71 | loss: 0.35967 | val_0_auc: 0.89585 |  0:00:12s
# epoch 72 | loss: 0.39244 | val_0_auc: 0.90095 |  0:00:12s
# epoch 73 | loss: 0.33161 | val_0_auc: 0.89009 |  0:00:12s
# epoch 74 | loss: 0.34396 | val_0_auc: 0.89417 |  0:00:12s
# epoch 75 | loss: 0.3481  | val_0_auc: 0.89286 |  0:00:13s
# epoch 76 | loss: 0.32823 | val_0_auc: 0.89089 |  0:00:13s
# epoch 77 | loss: 0.3369  | val_0_auc: 0.89803 |  0:00:13s
# epoch 78 | loss: 0.33315 | val_0_auc: 0.89803 |  0:00:13s
# epoch 79 | loss: 0.35041 | val_0_auc: 0.89628 |  0:00:13s
# epoch 80 | loss: 0.37736 | val_0_auc: 0.9008  |  0:00:13s
# epoch 81 | loss: 0.3737  | val_0_auc: 0.88812 |  0:00:14s
# epoch 82 | loss: 0.38178 | val_0_auc: 0.88863 |  0:00:14s
# epoch 83 | loss: 0.38949 | val_0_auc: 0.89023 |  0:00:14s
#
# Early stopping occurred at epoch 83 with best_epoch = 63 and best_val_0_auc = 0.90882
# Fold 2 AUC: 0.9088
# /usr/local/lib/python3.12/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /usr/local/lib/python3.12/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 0.98898 | val_0_auc: 0.49804 |  0:00:00s
# epoch 1  | loss: 0.96877 | val_0_auc: 0.66546 |  0:00:00s
# epoch 2  | loss: 0.83522 | val_0_auc: 0.73123 |  0:00:00s
# epoch 3  | loss: 0.72133 | val_0_auc: 0.75969 |  0:00:00s
# epoch 4  | loss: 0.72919 | val_0_auc: 0.7753  |  0:00:01s
# epoch 5  | loss: 0.57423 | val_0_auc: 0.77537 |  0:00:01s
# epoch 6  | loss: 0.62575 | val_0_auc: 0.79381 |  0:00:01s
# epoch 7  | loss: 0.60765 | val_0_auc: 0.81371 |  0:00:01s
# epoch 8  | loss: 0.64488 | val_0_auc: 0.83832 |  0:00:02s
# epoch 9  | loss: 0.69351 | val_0_auc: 0.83592 |  0:00:02s
# epoch 10 | loss: 0.59896 | val_0_auc: 0.82452 |  0:00:02s
# epoch 11 | loss: 0.54367 | val_0_auc: 0.85894 |  0:00:02s
# epoch 12 | loss: 0.62536 | val_0_auc: 0.86845 |  0:00:02s
# epoch 13 | loss: 0.61011 | val_0_auc: 0.86598 |  0:00:03s
# epoch 14 | loss: 0.55063 | val_0_auc: 0.8622  |  0:00:03s
# epoch 15 | loss: 0.58264 | val_0_auc: 0.84696 |  0:00:03s
# epoch 16 | loss: 0.59902 | val_0_auc: 0.85886 |  0:00:03s
# epoch 17 | loss: 0.66611 | val_0_auc: 0.86075 |  0:00:03s
# epoch 18 | loss: 0.57226 | val_0_auc: 0.87034 |  0:00:03s
# epoch 19 | loss: 0.54384 | val_0_auc: 0.85945 |  0:00:03s
# epoch 20 | loss: 0.51433 | val_0_auc: 0.86148 |  0:00:04s
# epoch 21 | loss: 0.54905 | val_0_auc: 0.86206 |  0:00:04s
# epoch 22 | loss: 0.53409 | val_0_auc: 0.87106 |  0:00:04s
# epoch 23 | loss: 0.59816 | val_0_auc: 0.87963 |  0:00:04s
# epoch 24 | loss: 0.45782 | val_0_auc: 0.88123 |  0:00:04s
# epoch 25 | loss: 0.50941 | val_0_auc: 0.86453 |  0:00:04s
# epoch 26 | loss: 0.50652 | val_0_auc: 0.88282 |  0:00:05s
# epoch 27 | loss: 0.50405 | val_0_auc: 0.87687 |  0:00:05s
# epoch 28 | loss: 0.48955 | val_0_auc: 0.87977 |  0:00:05s
# epoch 29 | loss: 0.47102 | val_0_auc: 0.88166 |  0:00:05s
# epoch 30 | loss: 0.52893 | val_0_auc: 0.88311 |  0:00:05s
# epoch 31 | loss: 0.50708 | val_0_auc: 0.88326 |  0:00:05s
# epoch 32 | loss: 0.44466 | val_0_auc: 0.8805  |  0:00:06s
# epoch 33 | loss: 0.49492 | val_0_auc: 0.88674 |  0:00:06s
# epoch 34 | loss: 0.47625 | val_0_auc: 0.88326 |  0:00:06s
# epoch 35 | loss: 0.53002 | val_0_auc: 0.87948 |  0:00:06s
# epoch 36 | loss: 0.48388 | val_0_auc: 0.89139 |  0:00:06s
# epoch 37 | loss: 0.48387 | val_0_auc: 0.89546 |  0:00:06s
# epoch 38 | loss: 0.48325 | val_0_auc: 0.90664 |  0:00:07s
# epoch 39 | loss: 0.46152 | val_0_auc: 0.90968 |  0:00:07s
# epoch 40 | loss: 0.51348 | val_0_auc: 0.90823 |  0:00:07s
# epoch 41 | loss: 0.42327 | val_0_auc: 0.89952 |  0:00:07s
# epoch 42 | loss: 0.4093  | val_0_auc: 0.88849 |  0:00:07s
# epoch 43 | loss: 0.43296 | val_0_auc: 0.88573 |  0:00:07s
# epoch 44 | loss: 0.45263 | val_0_auc: 0.86743 |  0:00:07s
# epoch 45 | loss: 0.47506 | val_0_auc: 0.87019 |  0:00:08s
# epoch 46 | loss: 0.4583  | val_0_auc: 0.86278 |  0:00:08s
# epoch 47 | loss: 0.48004 | val_0_auc: 0.86743 |  0:00:08s
# epoch 48 | loss: 0.47214 | val_0_auc: 0.87063 |  0:00:08s
# epoch 49 | loss: 0.47787 | val_0_auc: 0.87309 |  0:00:08s
# epoch 50 | loss: 0.52721 | val_0_auc: 0.86322 |  0:00:08s
# epoch 51 | loss: 0.42357 | val_0_auc: 0.86917 |  0:00:09s
# epoch 52 | loss: 0.47722 | val_0_auc: 0.8654  |  0:00:09s
# epoch 53 | loss: 0.44053 | val_0_auc: 0.87005 |  0:00:09s
# epoch 54 | loss: 0.40484 | val_0_auc: 0.87774 |  0:00:09s
# epoch 55 | loss: 0.36182 | val_0_auc: 0.87455 |  0:00:09s
# epoch 56 | loss: 0.43873 | val_0_auc: 0.87687 |  0:00:09s
# epoch 57 | loss: 0.40487 | val_0_auc: 0.87324 |  0:00:10s
# epoch 58 | loss: 0.38786 | val_0_auc: 0.86278 |  0:00:10s
# epoch 59 | loss: 0.40291 | val_0_auc: 0.86424 |  0:00:10s
#
# Early stopping occurred at epoch 59 with best_epoch = 39 and best_val_0_auc = 0.90968
# Fold 3 AUC: 0.9097
# /usr/local/lib/python3.12/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /usr/local/lib/python3.12/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 1.00963 | val_0_auc: 0.52142 |  0:00:00s
# epoch 1  | loss: 0.87543 | val_0_auc: 0.69217 |  0:00:00s
# epoch 2  | loss: 0.95094 | val_0_auc: 0.75846 |  0:00:00s
# epoch 3  | loss: 0.8139  | val_0_auc: 0.75338 |  0:00:00s
# epoch 4  | loss: 0.70282 | val_0_auc: 0.75512 |  0:00:00s
# epoch 5  | loss: 0.61536 | val_0_auc: 0.78561 |  0:00:00s
# epoch 6  | loss: 0.68015 | val_0_auc: 0.86729 |  0:00:01s
# epoch 7  | loss: 0.62519 | val_0_auc: 0.90598 |  0:00:01s
# epoch 8  | loss: 0.64733 | val_0_auc: 0.8866  |  0:00:01s
# epoch 9  | loss: 0.63341 | val_0_auc: 0.86838 |  0:00:01s
# epoch 10 | loss: 0.53995 | val_0_auc: 0.89204 |  0:00:01s
# epoch 11 | loss: 0.52962 | val_0_auc: 0.87251 |  0:00:01s
# epoch 12 | loss: 0.59369 | val_0_auc: 0.86235 |  0:00:02s
# epoch 13 | loss: 0.53407 | val_0_auc: 0.86409 |  0:00:03s
# epoch 14 | loss: 0.53321 | val_0_auc: 0.87694 |  0:00:03s
# epoch 15 | loss: 0.5169  | val_0_auc: 0.87876 |  0:00:03s
# epoch 16 | loss: 0.56441 | val_0_auc: 0.87019 |  0:00:03s
# epoch 17 | loss: 0.54036 | val_0_auc: 0.87288 |  0:00:04s
# epoch 18 | loss: 0.49316 | val_0_auc: 0.86387 |  0:00:04s
# epoch 19 | loss: 0.51288 | val_0_auc: 0.86932 |  0:00:04s
# epoch 20 | loss: 0.52498 | val_0_auc: 0.86663 |  0:00:04s
# epoch 21 | loss: 0.48972 | val_0_auc: 0.87157 |  0:00:05s
# epoch 22 | loss: 0.58062 | val_0_auc: 0.85574 |  0:00:05s
# epoch 23 | loss: 0.58396 | val_0_auc: 0.8736  |  0:00:05s
# epoch 24 | loss: 0.49024 | val_0_auc: 0.87803 |  0:00:05s
# epoch 25 | loss: 0.5337  | val_0_auc: 0.87324 |  0:00:05s
# epoch 26 | loss: 0.47561 | val_0_auc: 0.87106 |  0:00:05s
# epoch 27 | loss: 0.46374 | val_0_auc: 0.86743 |  0:00:06s
#
# Early stopping occurred at epoch 27 with best_epoch = 7 and best_val_0_auc = 0.90598
# Fold 4 AUC: 0.9060
# /usr/local/lib/python3.12/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# /usr/local/lib/python3.12/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 1.00355 | val_0_auc: 0.48748 |  0:00:00s
# epoch 1  | loss: 0.8633  | val_0_auc: 0.61532 |  0:00:00s
# epoch 2  | loss: 0.73813 | val_0_auc: 0.71973 |  0:00:00s
# epoch 3  | loss: 0.76468 | val_0_auc: 0.68365 |  0:00:00s
# epoch 4  | loss: 0.66081 | val_0_auc: 0.71804 |  0:00:00s
# epoch 5  | loss: 0.65688 | val_0_auc: 0.73137 |  0:00:00s
# epoch 6  | loss: 0.57154 | val_0_auc: 0.77511 |  0:00:01s
# epoch 7  | loss: 0.6623  | val_0_auc: 0.81672 |  0:00:01s
# epoch 8  | loss: 0.59533 | val_0_auc: 0.83247 |  0:00:01s
# epoch 9  | loss: 0.57362 | val_0_auc: 0.81208 |  0:00:01s
# epoch 10 | loss: 0.63028 | val_0_auc: 0.82106 |  0:00:01s
# epoch 11 | loss: 0.51463 | val_0_auc: 0.838   |  0:00:01s
# epoch 12 | loss: 0.54249 | val_0_auc: 0.82246 |  0:00:02s
# epoch 13 | loss: 0.56928 | val_0_auc: 0.80088 |  0:00:02s
# epoch 14 | loss: 0.52416 | val_0_auc: 0.81267 |  0:00:02s
# epoch 15 | loss: 0.58929 | val_0_auc: 0.82828 |  0:00:02s
# epoch 16 | loss: 0.45016 | val_0_auc: 0.81605 |  0:00:02s
# epoch 17 | loss: 0.49549 | val_0_auc: 0.8162  |  0:00:02s
# epoch 18 | loss: 0.58272 | val_0_auc: 0.84624 |  0:00:03s
# epoch 19 | loss: 0.54235 | val_0_auc: 0.84624 |  0:00:03s
# epoch 20 | loss: 0.54635 | val_0_auc: 0.82533 |  0:00:03s
# epoch 21 | loss: 0.51799 | val_0_auc: 0.82769 |  0:00:03s
# epoch 22 | loss: 0.5327  | val_0_auc: 0.83535 |  0:00:04s
# epoch 23 | loss: 0.45991 | val_0_auc: 0.8299  |  0:00:04s
# epoch 24 | loss: 0.57092 | val_0_auc: 0.83741 |  0:00:04s
# epoch 25 | loss: 0.40023 | val_0_auc: 0.84212 |  0:00:04s
# epoch 26 | loss: 0.40718 | val_0_auc: 0.84256 |  0:00:04s
# epoch 27 | loss: 0.52486 | val_0_auc: 0.84227 |  0:00:05s
# epoch 28 | loss: 0.49169 | val_0_auc: 0.8433  |  0:00:05s
# epoch 29 | loss: 0.47051 | val_0_auc: 0.84816 |  0:00:05s
# epoch 30 | loss: 0.44264 | val_0_auc: 0.84963 |  0:00:05s
# epoch 31 | loss: 0.46424 | val_0_auc: 0.85817 |  0:00:05s
# epoch 32 | loss: 0.40496 | val_0_auc: 0.85891 |  0:00:05s
# epoch 33 | loss: 0.39989 | val_0_auc: 0.85847 |  0:00:06s
# epoch 34 | loss: 0.40049 | val_0_auc: 0.85037 |  0:00:06s
# epoch 35 | loss: 0.41289 | val_0_auc: 0.84993 |  0:00:06s
# epoch 36 | loss: 0.4458  | val_0_auc: 0.85567 |  0:00:06s
# epoch 37 | loss: 0.39085 | val_0_auc: 0.85346 |  0:00:06s
# epoch 38 | loss: 0.4026  | val_0_auc: 0.8486  |  0:00:06s
# epoch 39 | loss: 0.4674  | val_0_auc: 0.84566 |  0:00:06s
# epoch 40 | loss: 0.41109 | val_0_auc: 0.84728 |  0:00:07s
# epoch 41 | loss: 0.44416 | val_0_auc: 0.85184 |  0:00:07s
# epoch 42 | loss: 0.45255 | val_0_auc: 0.85596 |  0:00:07s
# epoch 43 | loss: 0.45203 | val_0_auc: 0.86362 |  0:00:07s
# epoch 44 | loss: 0.38563 | val_0_auc: 0.83918 |  0:00:07s
# epoch 45 | loss: 0.3591  | val_0_auc: 0.83697 |  0:00:07s
# epoch 46 | loss: 0.4314  | val_0_auc: 0.83652 |  0:00:08s
# epoch 47 | loss: 0.38648 | val_0_auc: 0.85007 |  0:00:08s
# epoch 48 | loss: 0.44937 | val_0_auc: 0.84772 |  0:00:08s
# epoch 49 | loss: 0.36856 | val_0_auc: 0.85191 |  0:00:08s
# epoch 50 | loss: 0.41003 | val_0_auc: 0.86163 |  0:00:08s
# epoch 51 | loss: 0.39445 | val_0_auc: 0.85486 |  0:00:08s
# epoch 52 | loss: 0.45398 | val_0_auc: 0.85103 |  0:00:09s
# epoch 53 | loss: 0.37553 | val_0_auc: 0.84853 |  0:00:09s
# epoch 54 | loss: 0.40983 | val_0_auc: 0.85295 |  0:00:09s
# epoch 55 | loss: 0.37672 | val_0_auc: 0.85361 |  0:00:09s
# epoch 56 | loss: 0.42179 | val_0_auc: 0.85847 |  0:00:09s
# epoch 57 | loss: 0.37185 | val_0_auc: 0.85191 |  0:00:10s
# epoch 58 | loss: 0.38817 | val_0_auc: 0.86097 |  0:00:10s
# epoch 59 | loss: 0.40076 | val_0_auc: 0.8651  |  0:00:10s
# epoch 60 | loss: 0.43232 | val_0_auc: 0.87143 |  0:00:10s
# epoch 61 | loss: 0.39611 | val_0_auc: 0.86819 |  0:00:11s
# epoch 62 | loss: 0.47648 | val_0_auc: 0.86642 |  0:00:11s
# epoch 63 | loss: 0.42669 | val_0_auc: 0.8732  |  0:00:11s
# epoch 64 | loss: 0.3943  | val_0_auc: 0.87113 |  0:00:11s
# epoch 65 | loss: 0.37582 | val_0_auc: 0.86686 |  0:00:12s
# epoch 66 | loss: 0.41144 | val_0_auc: 0.87231 |  0:00:12s
# epoch 67 | loss: 0.41778 | val_0_auc: 0.87172 |  0:00:12s
# epoch 68 | loss: 0.40036 | val_0_auc: 0.86848 |  0:00:12s
# epoch 69 | loss: 0.36494 | val_0_auc: 0.86878 |  0:00:12s
# epoch 70 | loss: 0.33391 | val_0_auc: 0.87099 |  0:00:12s
# epoch 71 | loss: 0.34892 | val_0_auc: 0.87054 |  0:00:13s
# epoch 72 | loss: 0.37904 | val_0_auc: 0.87496 |  0:00:13s
# epoch 73 | loss: 0.33552 | val_0_auc: 0.87968 |  0:00:13s
# epoch 74 | loss: 0.35713 | val_0_auc: 0.88144 |  0:00:13s
# epoch 75 | loss: 0.40046 | val_0_auc: 0.88203 |  0:00:13s
# epoch 76 | loss: 0.3551  | val_0_auc: 0.87806 |  0:00:13s
# epoch 77 | loss: 0.31987 | val_0_auc: 0.87658 |  0:00:13s
# epoch 78 | loss: 0.38967 | val_0_auc: 0.87437 |  0:00:14s
# epoch 79 | loss: 0.38094 | val_0_auc: 0.8718  |  0:00:14s
# epoch 80 | loss: 0.40856 | val_0_auc: 0.88468 |  0:00:14s
# epoch 81 | loss: 0.38587 | val_0_auc: 0.90088 |  0:00:14s
# epoch 82 | loss: 0.37503 | val_0_auc: 0.88895 |  0:00:14s
# epoch 83 | loss: 0.3436  | val_0_auc: 0.88586 |  0:00:14s
# epoch 84 | loss: 0.35028 | val_0_auc: 0.8947  |  0:00:15s
# epoch 85 | loss: 0.36785 | val_0_auc: 0.89102 |  0:00:15s
# epoch 86 | loss: 0.36189 | val_0_auc: 0.8891  |  0:00:15s
# epoch 87 | loss: 0.38176 | val_0_auc: 0.89529 |  0:00:15s
# epoch 88 | loss: 0.32786 | val_0_auc: 0.90059 |  0:00:15s
# epoch 89 | loss: 0.33415 | val_0_auc: 0.90677 |  0:00:15s
# epoch 90 | loss: 0.33239 | val_0_auc: 0.91222 |  0:00:16s
# epoch 91 | loss: 0.38492 | val_0_auc: 0.91267 |  0:00:16s
# epoch 92 | loss: 0.34185 | val_0_auc: 0.90943 |  0:00:16s
# epoch 93 | loss: 0.39073 | val_0_auc: 0.9081  |  0:00:16s
# epoch 94 | loss: 0.37243 | val_0_auc: 0.90221 |  0:00:16s
# epoch 95 | loss: 0.37178 | val_0_auc: 0.89647 |  0:00:16s
# epoch 96 | loss: 0.37241 | val_0_auc: 0.89971 |  0:00:16s
# epoch 97 | loss: 0.40968 | val_0_auc: 0.89867 |  0:00:17s
# epoch 98 | loss: 0.39638 | val_0_auc: 0.89823 |  0:00:17s
# epoch 99 | loss: 0.34497 | val_0_auc: 0.90162 |  0:00:17s
# epoch 100| loss: 0.37326 | val_0_auc: 0.90221 |  0:00:17s
# epoch 101| loss: 0.35963 | val_0_auc: 0.90265 |  0:00:17s
# epoch 102| loss: 0.39263 | val_0_auc: 0.9     |  0:00:17s
# epoch 103| loss: 0.38807 | val_0_auc: 0.90147 |  0:00:18s
# epoch 104| loss: 0.35622 | val_0_auc: 0.89809 |  0:00:18s
# epoch 105| loss: 0.36768 | val_0_auc: 0.89632 |  0:00:18s
# epoch 106| loss: 0.37581 | val_0_auc: 0.89087 |  0:00:18s
# epoch 107| loss: 0.35024 | val_0_auc: 0.89264 |  0:00:18s
# epoch 108| loss: 0.36581 | val_0_auc: 0.88851 |  0:00:18s
# epoch 109| loss: 0.38575 | val_0_auc: 0.88792 |  0:00:19s
# epoch 110| loss: 0.34087 | val_0_auc: 0.88409 |  0:00:19s
# epoch 111| loss: 0.37778 | val_0_auc: 0.88616 |  0:00:19s
#
# Early stopping occurred at epoch 111 with best_epoch = 91 and best_val_0_auc = 0.91267
# Fold 5 AUC: 0.9127
# TabNet Mean AUC: 0.9078
# Logistic Regression Best threshold: 0.4002 Best F1: 0.8605
# Random Forest Best threshold: 0.4467 Best F1: 0.8598
# XGBoost Best threshold: 0.2777 Best F1: 0.8571
# LightGBM Best threshold: 0.384 Best F1: 0.8464
# TabNet Best threshold: 0.2888 Best F1: 0.8244
#
# Final Results
#                  Model       AUC  Accuracy        F1  Precision    Recall  \
# 1        Random Forest  0.922558  0.872467  0.859764   0.798054  0.931818
# 2              XGBoost  0.918319  0.868892  0.857143   0.789474  0.937500
# 3             LightGBM  0.917106  0.859356  0.846354   0.781250  0.923295
# 0  Logistic Regression  0.916879  0.873659  0.860526   0.801471  0.928977
# 4               TabNet  0.900673  0.835518  0.824427   0.746544  0.920455
#
#       Brier
# 1  0.100804
# 2  0.107269
# 3  0.106687
# 0  0.103433
# 4  0.123215
# /usr/local/lib/python3.12/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# AUC 95% Confidence Intervals
# Logistic Regression CI: [0.89734028 0.93586701]
# Random Forest CI: [0.90423357 0.9402973 ]
# XGBoost CI: [0.89930658 0.93675964]
# LightGBM CI: [0.89750754 0.93550622]
# TabNet CI: [0.87830563 0.92076464]
# Running SHAP analysis
